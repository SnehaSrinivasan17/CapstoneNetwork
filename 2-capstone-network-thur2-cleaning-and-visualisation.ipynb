# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %% [markdown]
# # Thursday 22 - 02 - 2018

# %% [markdown]
# **Data information**

# %%
thur2 = pd.read_csv('/kaggle/input/cic-ids-2018-thur-2/Thursday-22-02-2018_TrafficForML_CICFlowMeter.csv')
thur2.head() #first 5 rows
# this dataset contains certain rows in which all the values in the row are filled with the header values
# Out:
#    Dst Port  Protocol            Timestamp  Flow Duration  Tot Fwd Pkts  \
# 0        22         6  22/02/2018 08:26:03       20553406            10
# 1     34989         6  22/02/2018 08:26:24            790             2
# 2       500        17  22/02/2018 08:25:10       99745913             5
# 3       500        17  22/02/2018 08:25:10       99745913             5
# 4       500        17  22/02/2018 08:24:59       89481361             6
#
#    Tot Bwd Pkts  TotLen Fwd Pkts  TotLen Bwd Pkts  Fwd Pkt Len Max  \
# 0             7             1063             1297              744
# 1             0              848                0              848
# 2             0             2500                0              500
# 3             0             2500                0              500
# 4             0             3000                0              500
#
#    Fwd Pkt Len Min  ...  Fwd Seg Size Min  Active Mean  Active Std  \
# ...

# %%
thur2.shape #number of rows and columns
# Out:
# (1048575, 80)

# %%
print(thur2['Label'].value_counts())
# Out:
# Benign              1048213
# Brute Force -Web        249
# Brute Force -XSS         79
# SQL Injection            34
# Name: Label, dtype: int64

# %%
thur2.info() #columns and their datatypes
#everything is object type so will have to convert them into the correct data type
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 80 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   Dst Port           1048575 non-null  int64
#  1   Protocol           1048575 non-null  int64
#  2   Timestamp          1048575 non-null  object
#  3   Flow Duration      1048575 non-null  int64
#  4   Tot Fwd Pkts       1048575 non-null  int64
#  5   Tot Bwd Pkts       1048575 non-null  int64
#  6   TotLen Fwd Pkts    1048575 non-null  int64
#  7   TotLen Bwd Pkts    1048575 non-null  int64
#  8   Fwd Pkt Len Max    1048575 non-null  int64
#  9   Fwd Pkt Len Min    1048575 non-null  int64
#  10  Fwd Pkt Len Mean   1048575 non-null  float64
#  11  Fwd Pkt Len Std    1048575 non-null  float64
#  12  Bwd Pkt Len Max    1048575 non-null  int64
#  13  Bwd Pkt Len Min    1048575 non-null  int64
#  14  Bwd Pkt Len Mean   1048575 non-null  float64
# ...

# %%
thur2_df = len(thur2[thur2["Protocol"]=="Protocol"]) #33 rows in which the values are the headers - this does not include the header row , thus we can drop them
print(thur2_df)
# Out:
# 0

# %%
#deleting the 33 rows
thur2.drop(thur2[thur2["Protocol"]=="Protocol"].index, inplace = True)
print(len(thur2)) # 613104 - 33
# Out:
# 1048575

# %%
thur2.info() #columns and their datatypes - after removing the 33 values
#have to convert to correct datatype
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 80 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   Dst Port           1048575 non-null  int64
#  1   Protocol           1048575 non-null  int64
#  2   Timestamp          1048575 non-null  object
#  3   Flow Duration      1048575 non-null  int64
#  4   Tot Fwd Pkts       1048575 non-null  int64
#  5   Tot Bwd Pkts       1048575 non-null  int64
#  6   TotLen Fwd Pkts    1048575 non-null  int64
#  7   TotLen Bwd Pkts    1048575 non-null  int64
#  8   Fwd Pkt Len Max    1048575 non-null  int64
#  9   Fwd Pkt Len Min    1048575 non-null  int64
#  10  Fwd Pkt Len Mean   1048575 non-null  float64
#  11  Fwd Pkt Len Std    1048575 non-null  float64
#  12  Bwd Pkt Len Max    1048575 non-null  int64
#  13  Bwd Pkt Len Min    1048575 non-null  int64
#  14  Bwd Pkt Len Mean   1048575 non-null  float64
# ...

# %%
#converting to the correct datatype
thur2['Dst Port'] = thur2['Dst Port'].astype(int)
thur2['Protocol'] = thur2['Protocol'].astype(int)
thur2['Flow Duration'] = thur2['Flow Duration'].astype(int)
thur2['Tot Fwd Pkts'] = thur2['Tot Fwd Pkts'].astype(int)
thur2['Tot Bwd Pkts'] = thur2['Tot Bwd Pkts'].astype(int)
thur2['TotLen Fwd Pkts'] = thur2['TotLen Fwd Pkts'].astype(int)
thur2['TotLen Bwd Pkts'] = thur2['TotLen Bwd Pkts'].astype(int)
thur2['Fwd Pkt Len Max'] = thur2['Fwd Pkt Len Max'].astype(int)
thur2['Fwd Pkt Len Min'] = thur2['Fwd Pkt Len Min'].astype(int)
thur2['Fwd Pkt Len Mean'] = thur2['Fwd Pkt Len Mean'].astype(float)
thur2['Fwd Pkt Len Std'] = thur2['Fwd Pkt Len Std'].astype(float)
thur2['Bwd Pkt Len Max'] = thur2['Bwd Pkt Len Max'].astype(int)
thur2['Bwd Pkt Len Min'] = thur2['Bwd Pkt Len Min'].astype(int)
thur2['Bwd Pkt Len Mean'] = thur2['Bwd Pkt Len Mean'].astype(float)
thur2['Bwd Pkt Len Std'] = thur2['Bwd Pkt Len Std'].astype(float)
thur2['Flow Byts/s'] = thur2['Flow Byts/s'].astype(float)
thur2['Flow Pkts/s'] = thur2['Flow Pkts/s'].astype(float)
thur2['Flow IAT Mean'] = thur2['Flow IAT Mean'].astype(float)
thur2['Flow IAT Std'] = thur2['Flow IAT Std'].astype(float)
thur2['Flow IAT Max'] = thur2['Flow IAT Max'].astype(int)
thur2['Flow IAT Min'] = thur2['Flow IAT Min'].astype(int)
thur2['Fwd IAT Tot'] = thur2['Fwd IAT Tot'].astype(int)
thur2['Fwd IAT Mean'] = thur2['Fwd IAT Mean'].astype(float)
thur2['Fwd IAT Std'] = thur2['Fwd IAT Std'].astype(float)
thur2['Fwd IAT Max'] = thur2['Fwd IAT Max'].astype(int)
thur2['Fwd IAT Min'] = thur2['Fwd IAT Min'].astype(int)
thur2['Bwd IAT Tot'] = thur2['Bwd IAT Tot'].astype(int)
thur2['Bwd IAT Mean'] = thur2['Bwd IAT Mean'].astype(float)
thur2['Bwd IAT Std'] = thur2['Bwd IAT Std'].astype(float)
thur2['Bwd IAT Max'] = thur2['Bwd IAT Max'].astype(int)
thur2['Bwd IAT Min'] = thur2['Bwd IAT Min'].astype(int)
thur2['Fwd PSH Flags'] = thur2['Fwd PSH Flags'].astype(int)
thur2['Bwd PSH Flags'] = thur2['Bwd PSH Flags'].astype(int)
thur2['Fwd URG Flags'] = thur2['Fwd URG Flags'].astype(int)
thur2['Bwd URG Flags'] = thur2['Bwd URG Flags'].astype(int)
thur2['Fwd Header Len'] = thur2['Fwd Header Len'].astype(int)
thur2['Bwd Header Len'] = thur2['Bwd Header Len'].astype(int)
thur2['Fwd Pkts/s'] = thur2['Fwd Pkts/s'].astype(float)
thur2['Bwd Pkts/s'] = thur2['Bwd Pkts/s'].astype(float)
thur2['Pkt Len Min'] = thur2['Pkt Len Min'].astype(int)
thur2['Pkt Len Max'] = thur2['Pkt Len Max'].astype(int)
thur2['Pkt Len Mean'] = thur2['Pkt Len Mean'].astype(float)
thur2['Pkt Len Std'] = thur2['Pkt Len Std'].astype(float)
thur2['Pkt Len Var'] = thur2['Pkt Len Var'].astype(float)
thur2['FIN Flag Cnt'] = thur2['FIN Flag Cnt'].astype(int)
thur2['SYN Flag Cnt'] = thur2['SYN Flag Cnt'].astype(int)
thur2['RST Flag Cnt'] = thur2['RST Flag Cnt'].astype(int)
thur2['PSH Flag Cnt'] = thur2['PSH Flag Cnt'].astype(int)
thur2['ACK Flag Cnt'] = thur2['ACK Flag Cnt'].astype(int)
thur2['URG Flag Cnt'] = thur2['URG Flag Cnt'].astype(int)
thur2['CWE Flag Count'] = thur2['CWE Flag Count'].astype(int)
thur2['ECE Flag Cnt'] = thur2['ECE Flag Cnt'].astype(int)
thur2['Down/Up Ratio'] = thur2['Down/Up Ratio'].astype(int)
thur2['Pkt Size Avg'] = thur2['Pkt Size Avg'].astype(float)
thur2['Fwd Seg Size Avg'] = thur2['Fwd Seg Size Avg'].astype(float)
thur2['Bwd Seg Size Avg'] = thur2['Bwd Seg Size Avg'].astype(float)
thur2['Fwd Byts/b Avg'] = thur2['Fwd Byts/b Avg'].astype(int)
thur2['Fwd Pkts/b Avg'] = thur2['Fwd Pkts/b Avg'].astype(int)
thur2['Fwd Blk Rate Avg'] = thur2['Fwd Blk Rate Avg'].astype(int)
thur2['Bwd Byts/b Avg'] = thur2['Bwd Byts/b Avg'].astype(int)
thur2['Bwd Pkts/b Avg'] = thur2['Bwd Pkts/b Avg'].astype(int)
thur2['Bwd Blk Rate Avg'] = thur2['Bwd Blk Rate Avg'].astype(int)
thur2['Subflow Fwd Pkts'] = thur2['Subflow Fwd Pkts'].astype(int)
thur2['Subflow Fwd Byts'] = thur2['Subflow Fwd Byts'].astype(int)
thur2['Subflow Bwd Pkts'] = thur2['Subflow Bwd Pkts'].astype(int)
thur2['Subflow Bwd Byts'] = thur2['Subflow Bwd Byts'].astype(int)
thur2['Init Fwd Win Byts'] = thur2['Init Fwd Win Byts'].astype(int)
thur2['Init Bwd Win Byts'] = thur2['Init Bwd Win Byts'].astype(int)
thur2['Fwd Act Data Pkts'] = thur2['Fwd Act Data Pkts'].astype(int)
thur2['Fwd Seg Size Min'] = thur2['Fwd Seg Size Min'].astype(int)
thur2['Active Mean'] = thur2['Active Mean'].astype(float)
thur2['Active Std'] = thur2['Active Std'].astype(float)
thur2['Active Max'] = thur2['Active Max'].astype(int)
thur2['Active Min'] = thur2['Active Min'].astype(int)
thur2['Idle Mean'] = thur2['Idle Mean'].astype(float)
thur2['Idle Std'] = thur2['Idle Std'].astype(float)
thur2['Idle Max'] = thur2['Idle Max'].astype(int)
thur2['Idle Min'] = thur2['Idle Min'].astype(int)

# %%
thur2.info() #columns and their datatypes - after conversion
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 80 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   Dst Port           1048575 non-null  int64
#  1   Protocol           1048575 non-null  int64
#  2   Timestamp          1048575 non-null  object
#  3   Flow Duration      1048575 non-null  int64
#  4   Tot Fwd Pkts       1048575 non-null  int64
#  5   Tot Bwd Pkts       1048575 non-null  int64
#  6   TotLen Fwd Pkts    1048575 non-null  int64
#  7   TotLen Bwd Pkts    1048575 non-null  int64
#  8   Fwd Pkt Len Max    1048575 non-null  int64
#  9   Fwd Pkt Len Min    1048575 non-null  int64
#  10  Fwd Pkt Len Mean   1048575 non-null  float64
#  11  Fwd Pkt Len Std    1048575 non-null  float64
#  12  Bwd Pkt Len Max    1048575 non-null  int64
#  13  Bwd Pkt Len Min    1048575 non-null  int64
#  14  Bwd Pkt Len Mean   1048575 non-null  float64
# ...

# %%
thur2.describe() #basic statistical computations
# Out:
#            Dst Port      Protocol  Flow Duration  Tot Fwd Pkts  Tot Bwd Pkts  \
# count  1.048575e+06  1.048575e+06   1.048575e+06  1.048575e+06  1.048575e+06
# mean   8.972819e+03  9.117318e+00   1.493482e+07  6.366313e+00  8.225241e+00
# std    1.810954e+04  5.113324e+00   1.475475e+09  7.134356e+01  2.035931e+02
# min    0.000000e+00  0.000000e+00  -8.282200e+11  1.000000e+00  0.000000e+00
# 25%    5.300000e+01  6.000000e+00   5.090000e+02  1.000000e+00  0.000000e+00
# 50%    4.430000e+02  6.000000e+00   8.159100e+04  2.000000e+00  1.000000e+00
# 75%    3.389000e+03  1.700000e+01   5.235859e+06  8.000000e+00  7.000000e+00
# max    6.553300e+04  1.700000e+01   1.200000e+08  1.147800e+04  3.841800e+04
#
#        TotLen Fwd Pkts  TotLen Bwd Pkts  Fwd Pkt Len Max  Fwd Pkt Len Min  \
# count     1.048575e+06     1.048575e+06     1.048575e+06     1.048575e+06
# mean      3.988747e+02     7.344806e+03     1.771716e+02     1.287449e+01
# ...

# %% [markdown]
# **Removing Null Values**

# %% [markdown]
# * Observed that only Flow Byt/s has null values
# * For NaN values when the Label is malicious - the values in the columns in the rows are not the same - so they are not duplicate , so maybe we will have to replace them
# * For NaN values when the Label is benign - the values in the columns in the rows are not the same - so they are not duplicate , so maybe we will have to replace them
#
# > If there is a missing value in only one row then it is advised to impute or change
# > If there are a large number of missing values in a row then we can drop it
#
# * i noticed that only sql injection needs FlowByt/s , so maybe it is not that important of a column to replace so we should just drop?

# %%
#null values
thur2_null_values = thur2.isnull().sum()
print(thur2_null_values.to_string())
# Out:
# Dst Port                0
# Protocol                0
# Timestamp               0
# Flow Duration           0
# Tot Fwd Pkts            0
# Tot Bwd Pkts            0
# TotLen Fwd Pkts         0
# TotLen Bwd Pkts         0
# Fwd Pkt Len Max         0
# Fwd Pkt Len Min         0
# Fwd Pkt Len Mean        0
# Fwd Pkt Len Std         0
# Bwd Pkt Len Max         0
# Bwd Pkt Len Min         0
# Bwd Pkt Len Mean        0
# Bwd Pkt Len Std         0
# Flow Byts/s          3569
# Flow Pkts/s             0
# Flow IAT Mean           0
# Flow IAT Std            0
# Flow IAT Max            0
# Flow IAT Min            0
# Fwd IAT Tot             0
# Fwd IAT Mean            0
# Fwd IAT Std             0
# Fwd IAT Max             0
# Fwd IAT Min             0
# Bwd IAT Tot             0
# Bwd IAT Mean            0
# Bwd IAT Std             0
# Bwd IAT Max             0
# Bwd IAT Min             0
# Fwd PSH Flags           0
# Bwd PSH Flags           0
# Fwd URG Flags           0
# ...

# %%
#nan values
thur2_nan_values = thur2.isna().sum()
print(thur2_nan_values.to_string())
# Out:
# Dst Port                0
# Protocol                0
# Timestamp               0
# Flow Duration           0
# Tot Fwd Pkts            0
# Tot Bwd Pkts            0
# TotLen Fwd Pkts         0
# TotLen Bwd Pkts         0
# Fwd Pkt Len Max         0
# Fwd Pkt Len Min         0
# Fwd Pkt Len Mean        0
# Fwd Pkt Len Std         0
# Bwd Pkt Len Max         0
# Bwd Pkt Len Min         0
# Bwd Pkt Len Mean        0
# Bwd Pkt Len Std         0
# Flow Byts/s          3569
# Flow Pkts/s             0
# Flow IAT Mean           0
# Flow IAT Std            0
# Flow IAT Max            0
# Flow IAT Min            0
# Fwd IAT Tot             0
# Fwd IAT Mean            0
# Fwd IAT Std             0
# Fwd IAT Max             0
# Fwd IAT Min             0
# Bwd IAT Tot             0
# Bwd IAT Mean            0
# Bwd IAT Std             0
# Bwd IAT Max             0
# Bwd IAT Min             0
# Fwd PSH Flags           0
# Bwd PSH Flags           0
# Fwd URG Flags           0
# ...

# %%
thur2.loc[thur2['Flow Byts/s'].isna()]
# Out:
#          Dst Port  Protocol            Timestamp  Flow Duration  Tot Fwd Pkts  \
# 3445        49738         6  22/02/2018 09:03:32              0             2
# 3767        49812         6  22/02/2018 09:15:00              0             2
# 3819        49862         6  22/02/2018 09:16:43              0             2
# 3916        49844         6  22/02/2018 09:18:41              0             2
# 4060        49971         6  22/02/2018 09:24:02              0             2
# ...           ...       ...                  ...            ...           ...
# 1042235       135         6  22/02/2018 05:29:15              0             2
# 1042292     52533         6  22/02/2018 04:41:24              0             2
# 1044766     50519         6  22/02/2018 10:58:54              0             2
# 1045718     50693         6  22/02/2018 11:25:17              0             2
# 1047696     50465         6  22/02/2018 10:49:59              0             2
#
# ...

# %%
#drop null values
thur2.dropna(axis=0,inplace=True)
print(thur2)
# Out:
#          Dst Port  Protocol            Timestamp  Flow Duration  Tot Fwd Pkts  \
# 0              22         6  22/02/2018 08:26:03       20553406            10
# 1           34989         6  22/02/2018 08:26:24            790             2
# 2             500        17  22/02/2018 08:25:10       99745913             5
# 3             500        17  22/02/2018 08:25:10       99745913             5
# 4             500        17  22/02/2018 08:24:59       89481361             6
# ...           ...       ...                  ...            ...           ...
# 1048570        53        17  22/02/2018 09:57:34          61898             2
# 1048571      1500         6  22/02/2018 04:51:29       86213373             2
# 1048572        53        17  22/02/2018 03:52:37            642             1
# 1048573        53        17  22/02/2018 09:40:42          78472             1
# 1048574      3389         6  22/02/2018 04:34:32        2013403             8
#
# ...

# %%
#null values after
thur2_null_values = thur2.isnull().sum()
print(thur2_null_values.to_string())
# Out:
# Dst Port             0
# Protocol             0
# Timestamp            0
# Flow Duration        0
# Tot Fwd Pkts         0
# Tot Bwd Pkts         0
# TotLen Fwd Pkts      0
# TotLen Bwd Pkts      0
# Fwd Pkt Len Max      0
# Fwd Pkt Len Min      0
# Fwd Pkt Len Mean     0
# Fwd Pkt Len Std      0
# Bwd Pkt Len Max      0
# Bwd Pkt Len Min      0
# Bwd Pkt Len Mean     0
# Bwd Pkt Len Std      0
# Flow Byts/s          0
# Flow Pkts/s          0
# Flow IAT Mean        0
# Flow IAT Std         0
# Flow IAT Max         0
# Flow IAT Min         0
# Fwd IAT Tot          0
# Fwd IAT Mean         0
# Fwd IAT Std          0
# Fwd IAT Max          0
# Fwd IAT Min          0
# Bwd IAT Tot          0
# Bwd IAT Mean         0
# Bwd IAT Std          0
# Bwd IAT Max          0
# Bwd IAT Min          0
# Fwd PSH Flags        0
# Bwd PSH Flags        0
# Fwd URG Flags        0
# Bwd URG Flags        0
# Fwd Header Len       0
# Bwd Header Len       0
# Fwd Pkts/s           0
# Bwd Pkts/s           0
# ...

# %%
#nan values after
thur2_null_values = thur2.isna().sum()
print(thur2_null_values.to_string())
# Out:
# Dst Port             0
# Protocol             0
# Timestamp            0
# Flow Duration        0
# Tot Fwd Pkts         0
# Tot Bwd Pkts         0
# TotLen Fwd Pkts      0
# TotLen Bwd Pkts      0
# Fwd Pkt Len Max      0
# Fwd Pkt Len Min      0
# Fwd Pkt Len Mean     0
# Fwd Pkt Len Std      0
# Bwd Pkt Len Max      0
# Bwd Pkt Len Min      0
# Bwd Pkt Len Mean     0
# Bwd Pkt Len Std      0
# Flow Byts/s          0
# Flow Pkts/s          0
# Flow IAT Mean        0
# Flow IAT Std         0
# Flow IAT Max         0
# Flow IAT Min         0
# Fwd IAT Tot          0
# Fwd IAT Mean         0
# Fwd IAT Std          0
# Fwd IAT Max          0
# Fwd IAT Min          0
# Bwd IAT Tot          0
# Bwd IAT Mean         0
# Bwd IAT Std          0
# Bwd IAT Max          0
# Bwd IAT Min          0
# Fwd PSH Flags        0
# Bwd PSH Flags        0
# Fwd URG Flags        0
# Bwd URG Flags        0
# Fwd Header Len       0
# Bwd Header Len       0
# Fwd Pkts/s           0
# Bwd Pkts/s           0
# ...

# %%
thur2.loc[thur2['Flow Byts/s'].isna()]
# Out:
# Empty DataFrame
# ...

# %% [markdown]
# **Infinite values**

# %% [markdown]
# * only Flow Byt/s and Flow Pkt/s have infinite values
# * i think we will have to replace all the rows which contain infinite values as, i noticed that every row which has the infinity value has different values in other columns in the row
# * some may be duplicate and well have to remove those under duplicate function
# * Flow Pkt/s is there in infiltration so maybe we do have to replace

# %%
ds = thur2.isin([np.inf, -np.inf])
print("Infinite values before:" ,ds)
# Out:
# Infinite values before:          Dst Port  Protocol  Timestamp  Flow Duration  Tot Fwd Pkts  \
# 0           False     False      False          False         False
# 1           False     False      False          False         False
# 2           False     False      False          False         False
# 3           False     False      False          False         False
# 4           False     False      False          False         False
# ...           ...       ...        ...            ...           ...
# 1048570     False     False      False          False         False
# 1048571     False     False      False          False         False
# 1048572     False     False      False          False         False
# 1048573     False     False      False          False         False
# 1048574     False     False      False          False         False
#
#          Tot Bwd Pkts  TotLen Fwd Pkts  TotLen Bwd Pkts  Fwd Pkt Len Max  \
# ...

# %%
thur2_data = thur2.iloc[:, 3:79]
thur2_inf_count = np.isinf(thur2_data.iloc[1:]).sum().sum()
print("Count of Infinite Values before:", thur2_inf_count)
# Out:
# Count of Infinite Values before: 4082

# %%
thur2_inf_values = np.isinf(thur2_data.iloc[1:]).sum()
print("Infinite values count before:", thur2_inf_values.to_string())
# Out:
# Infinite values count before: Flow Duration           0
# Tot Fwd Pkts            0
# Tot Bwd Pkts            0
# TotLen Fwd Pkts         0
# TotLen Bwd Pkts         0
# Fwd Pkt Len Max         0
# Fwd Pkt Len Min         0
# Fwd Pkt Len Mean        0
# Fwd Pkt Len Std         0
# Bwd Pkt Len Max         0
# Bwd Pkt Len Min         0
# Bwd Pkt Len Mean        0
# Bwd Pkt Len Std         0
# Flow Byts/s          2041
# Flow Pkts/s          2041
# Flow IAT Mean           0
# Flow IAT Std            0
# Flow IAT Max            0
# Flow IAT Min            0
# Fwd IAT Tot             0
# Fwd IAT Mean            0
# Fwd IAT Std             0
# Fwd IAT Max             0
# Fwd IAT Min             0
# Bwd IAT Tot             0
# Bwd IAT Mean            0
# Bwd IAT Std             0
# Bwd IAT Max             0
# Bwd IAT Min             0
# Fwd PSH Flags           0
# Bwd PSH Flags           0
# Fwd URG Flags           0
# Bwd URG Flags           0
# Fwd Header Len          0
# ...

# %%
#to remove infinity values 
thur2 = thur2.replace(["Infinity", "infinity"], np.inf)
thur2 = thur2.replace([np.inf, -np.inf], np.nan)
thur2.replace([np.inf, -np.inf], np.nan, inplace=True)
thur2.dropna(inplace=True)

# %%
ds = thur2.isin([np.inf, -np.inf])
print("Infinite values after:" ,ds)
# Out:
# Infinite values after:          Dst Port  Protocol  Timestamp  Flow Duration  Tot Fwd Pkts  \
# 0           False     False      False          False         False
# 1           False     False      False          False         False
# 2           False     False      False          False         False
# 3           False     False      False          False         False
# 4           False     False      False          False         False
# ...           ...       ...        ...            ...           ...
# 1048570     False     False      False          False         False
# 1048571     False     False      False          False         False
# 1048572     False     False      False          False         False
# 1048573     False     False      False          False         False
# 1048574     False     False      False          False         False
#
#          Tot Bwd Pkts  TotLen Fwd Pkts  TotLen Bwd Pkts  Fwd Pkt Len Max  \
# ...

# %%
thur2_data = thur2.iloc[:, 3:79]
thur2_inf_count = np.isinf(thur2_data.iloc[1:]).sum().sum()
print("Count of Infinite Values after:", thur2_inf_count)
# Out:
# Count of Infinite Values after: 0

# %%
thur2_inf_values = np.isinf(thur2_data.iloc[1:]).sum()
print("Infinite values count after:", thur2_inf_values.to_string())
# Out:
# Infinite values count after: Flow Duration        0
# Tot Fwd Pkts         0
# Tot Bwd Pkts         0
# TotLen Fwd Pkts      0
# TotLen Bwd Pkts      0
# Fwd Pkt Len Max      0
# Fwd Pkt Len Min      0
# Fwd Pkt Len Mean     0
# Fwd Pkt Len Std      0
# Bwd Pkt Len Max      0
# Bwd Pkt Len Min      0
# Bwd Pkt Len Mean     0
# Bwd Pkt Len Std      0
# Flow Byts/s          0
# Flow Pkts/s          0
# Flow IAT Mean        0
# Flow IAT Std         0
# Flow IAT Max         0
# Flow IAT Min         0
# Fwd IAT Tot          0
# Fwd IAT Mean         0
# Fwd IAT Std          0
# Fwd IAT Max          0
# Fwd IAT Min          0
# Bwd IAT Tot          0
# Bwd IAT Mean         0
# Bwd IAT Std          0
# Bwd IAT Max          0
# Bwd IAT Min          0
# Fwd PSH Flags        0
# Bwd PSH Flags        0
# Fwd URG Flags        0
# Bwd URG Flags        0
# Fwd Header Len       0
# Bwd Header Len       0
# Fwd Pkts/s           0
# Bwd Pkts/s           0
# Pkt Len Min          0
# ...

# %% [markdown]
# **Duplicate Values**

# %% [markdown]
# we do have to remove all the duplicates

# %%
print("Duplicate values before:")
thur2.duplicated()
# Out:
# Duplicate values before:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 1048570    False
# 1048571    False
# 1048572    False
# 1048573    False
# 1048574    False
# Length: 1042965, dtype: bool

# %%
print("Count of duplicate values before:")
thur2.duplicated().sum()
# Out:
# Count of duplicate values before:
# 3272

# %%
print("Duplicate values before (all occurences):") #interesting
thur2.loc[thur2.duplicated(keep=False), :]
# Out:
# Duplicate values before (all occurences):

# %%
print("Duplicate values before (first occurences):")
thur2.loc[thur2.duplicated(keep='first'), :] #keeping only the first occurence of the duplicate

# %%
# Use keep='first' to keep the first occurrence 
thur2.drop_duplicates(keep='first', inplace=True)

# %%
print("Duplicate values after:")
thur2.duplicated()

# %%
print("Count of duplicate values after:")
thur2.duplicated().sum()

# %%
print("Duplicate values after (all occurences):")
thur2.loc[thur2.duplicated(keep=False), :]

# %%
print("Duplicate values after (first occurences):")
thur2.loc[thur2.duplicated(keep='first'), :] #keeping only the first occurence of the duplicate

# %%
thur2.to_csv('thur2_nan_inf_dup.csv', index=False) # Save the updated dataset to a new file
